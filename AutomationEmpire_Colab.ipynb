# %% [markdown]
# # 👑 Automation Empire — AI Voice Studio
# > **600+ Languages · Voice Cloning · Voice Design · Zero-Shot TTS**
# ---
# ### ⚡ Sirf 2 steps — Run All dabao aur link copy karo!

# %%
# ── Step 1: Install + Apply Branding ──────────────────────
import subprocess, urllib.request, os, site

# Install omnivoice
subprocess.run(['pip', 'install', 'omnivoice', '-q'], check=True)

# Apply Automation Empire branding
for p in site.getsitepackages():
    candidate = os.path.join(p, 'omnivoice', 'cli', 'demo.py')
    if os.path.exists(candidate):
        urllib.request.urlretrieve(
            'https://raw.githubusercontent.com/mirzasaqibusa-oss/Automation-Empire/main/omnivoice/cli/demo.py',
            candidate
        )
        break

print('✅ Ready! Run Step 2 now!')

# %%
# ── Step 2: Launch 🚀 ──────────────────────────────────────
# 👇 Gradio public link neeche ayega — copy karke browser mein open karein!
# !omnivoice-demo --model k2-fsa/OmniVoice --share
